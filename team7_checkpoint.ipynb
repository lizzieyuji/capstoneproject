# %% [markdown]
# ## Capstone Project Checkpoint

# %% [markdown]
# What to acomplish:
# - basic outline for code
# - divide tasks among members
# - set up collaboration platforms

# %% [markdown]
# Outline:
# - divide the position axis into a finite grid, approximate the second derivative with a finite difference method, and use this to construct the Hamiltonian matrix
# - calculate Hamiltonian eigenvalues (allowed energy levels) and eigenvectors (corresponding wavefunctions)
# - compare the lowest few numerical energy levels with the analytic result
# - plots of the harmonic oscillator potential, first few wavefunctions, and a comparison between the numerical energy levels and the analytic values
# - test what happens when we change the grid spacing and the size of the numerical box
# <br>
# Suggestions from GSI:
#
# - Specify which numerical eigensolver you plan to use
# - quantitative error analysis when comparing numerical and analytical energy levels
# - plotting other metrics like probability densities in addition to just the wavefunctions (have to show two domains)

# %% [markdown]
# Lizzie's tasks:
# -

# %% [markdown]
# Keunmo's tasks:
# -

# %% [markdown]
# Brandon's tasks:
# -

# %% [markdown]
# Ryan's tasks:
# -
